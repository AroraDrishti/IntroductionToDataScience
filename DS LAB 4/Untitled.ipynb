# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df.columns
# Out:
# Index(['Car_Name', 'Year', 'Selling_Price', 'Present_Price', 'Kms_Driven',
#        'Fuel_Type', 'Seller_Type', 'Transmission', 'Owner'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Car_Name          object
# Year               int64
# Selling_Price    float64
# Present_Price    float64
# Kms_Driven         int64
# Fuel_Type         object
# Seller_Type       object
# Transmission      object
# Owner              int64
# dtype: object

# %%
df = pd.read_csv("car_data.csv")

# %%
df['Year']
# Out:
# 0      2014
# 1      2013
# 2      2017
# 3      2011
# 4      2014
#        ...
# 296    2016
# 297    2015
# 298    2009
# 299    2017
# 300    2016
# Name: Year, Length: 301, dtype: int64

# %%
#bar chart
sns.barplot(x=df['Year'], y =df['Selling_Price'], data = df, palette = "Blues")
plt.title('Bar Plot')
plt.xlabel()
plt.ylabel()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-b318537b6a09> in <module>
#       2 sns.barplot(x=df['Year'], y =df['Selling_Price'], data = df, palette = "Blues")
#       3 plt.title('Bar Plot')
# ----> 4 plt.xlabel()
#       5 plt.ylabel()
#       6 plt.show()
#
# TypeError: xlabel() missing 1 required positional argument: 'xlabel'

# %%
#histogram
sns.histplot(x=df['Kms_Driven'], data = df, palette = "Blues", bins = "auto")
# Out:
# <AxesSubplot:xlabel='Kms_Driven', ylabel='Count'>

# %%
#scatter plot
plt.scatter(data['Selling_Price'], data['Present_Price'], alpha = 0.5)
#alpha is intensity of points

# %%
#line chart
plt.plot(df['Selling_Price'], df['Present_Price'], alpha = 0.5)

# %%
df['Fuel_Type'].value_counts()
# Out:
# Petrol    239
# Diesel     60
# CNG         2
# Name: Fuel_Type, dtype: int64

# %%
X = df.groupby('Fuel_Type').size()

# %%
X
# Out:
# Fuel_Type
# CNG         2
# Diesel     60
# Petrol    239
# dtype: int64

# %%
def label_function(val)
    return f' {}%
#plt.pie(X, labels = None, autopct = False)
plt.pie(X, labels = None, autopct = label_function)

# %%
#area chart
# https://www.analyticsvidhya.com/blog/2021/02/an-intuitive-guide-to-visualization-in-python/

# %%
#distribution plot over histogram

# %%
#kutosis(peakedness of data) 
#for normal dist=3

# %%
#boxplot-outliers
