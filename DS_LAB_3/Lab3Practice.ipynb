# %% [markdown]
# Importing libraries

# %%
import pandas as pd
import numpy as np
import matplotlib as pyplot
import seaborn as sns

# %% [markdown]
# Importing dataset

# %%
data=pd.read_csv('income.csv')

# %% [markdown]
# Determining size of dataset

# %%
data.shape
# Out:
# (31978, 13)

# %% [markdown]
# Printing first 10 rows of dataset

# %%
data.head(10)
# Out:
#    age       JobType         EdType        maritalstatus          occupation  \
# 0   45       Private        HS-grad             Divorced        Adm-clerical
# 1   24   Federal-gov        HS-grad        Never-married        Armed-Forces
# 2   44       Private   Some-college   Married-civ-spouse      Prof-specialty
# 3   27       Private            9th        Never-married        Craft-repair
# 4   20       Private   Some-college        Never-married               Sales
# 5   44       Private        HS-grad              Widowed     Exec-managerial
# 6   51       Private        HS-grad   Married-civ-spouse        Craft-repair
# 7   20       Private        HS-grad   Married-civ-spouse   Machine-op-inspct
# 8   17             ?           11th        Never-married                   ?
# 9   19       Private        HS-grad        Never-married   Machine-op-inspct
#
#       relationship                 race   gender  capitalgain  capitalloss  \
# ...

# %% [markdown]
# Printing last 5 rows of dataset

# %%
data.tail()
# Out:
#        age     JobType         EdType        maritalstatus        occupation  \
# 31973   34   Local-gov        HS-grad        Never-married   Farming-fishing
# 31974   34   Local-gov   Some-college        Never-married   Protective-serv
# 31975   23     Private   Some-college   Married-civ-spouse      Adm-clerical
# 31976   42   Local-gov   Some-college   Married-civ-spouse      Adm-clerical
# 31977   29     Private      Bachelors        Never-married    Prof-specialty
#
#          relationship    race   gender  capitalgain  capitalloss  \
# 31973   Not-in-family   Black     Male          594            0
# 31974   Not-in-family   White   Female            0            0
# 31975         Husband   White     Male            0            0
# 31976            Wife   White   Female            0            0
# 31977   Not-in-family   White     Male            0            0
#
#        hoursperweek   nativecountry                        SalStat
# ...

# %% [markdown]
# Basic statistical details (for Numerical Variables)

# %%
data.describe()
# Out:
#                 age   capitalgain   capitalloss  hoursperweek
# count  31978.000000  31978.000000  31978.000000  31978.000000
# mean      38.579023   1064.360623     86.739352     40.417850
# std       13.662085   7298.596271    401.594301     12.345285
# min       17.000000      0.000000      0.000000      1.000000
# 25%       28.000000      0.000000      0.000000     40.000000
# 50%       37.000000      0.000000      0.000000     40.000000
# 75%       48.000000      0.000000      0.000000     45.000000
# max       90.000000  99999.000000   4356.000000     99.000000

# %% [markdown]
# Basic statistical details (for Categorical Variables)

# %%
data.describe(include="O")
# Out:
#          JobType    EdType        maritalstatus       occupation relationship  \
# count      31978     31978                31978            31978        31978
# unique         9        16                    7               15            6
# top      Private   HS-grad   Married-civ-spouse   Prof-specialty      Husband
# freq       22286     10368                14692             4038        12947
#
#           race gender   nativecountry                        SalStat
# count    31978  31978           31978                          31978
# unique       5      2              41                              2
# top      White   Male   United-States   less than or equal to 50,000
# freq     27430  21370           29170                          24283

# %% [markdown]
# Basic statistical details (for all Variables)

# %%
data.describe(include="all")
# Out:
#                  age   JobType    EdType        maritalstatus  \
# count   31978.000000     31978     31978                31978
# unique           NaN         9        16                    7
# top              NaN   Private   HS-grad   Married-civ-spouse
# freq             NaN     22286     10368                14692
# mean       38.579023       NaN       NaN                  NaN
# std        13.662085       NaN       NaN                  NaN
# min        17.000000       NaN       NaN                  NaN
# 25%        28.000000       NaN       NaN                  NaN
# 50%        37.000000       NaN       NaN                  NaN
# 75%        48.000000       NaN       NaN                  NaN
# max        90.000000       NaN       NaN                  NaN
#
#              occupation relationship    race gender   capitalgain  \
# count             31978        31978   31978  31978  31978.000000
# unique               15            6       5      2           NaN
# ...

# %% [markdown]
# Accessing a feature from dataset

# %%
data["hoursperweek"]
# Out:
# 0        28
# 1        40
# 2        40
# 3        40
# 4        35
#          ..
# 31973    60
# 31974    40
# 31975    40
# 31976    40
# 31977    40
# Name: hoursperweek, Length: 31978, dtype: int64

# %% [markdown]
# Determining and printing mean of a feature from dataset

# %%
mean = data["hoursperweek"].mean()
print(mean)
# Out:
# 40.41784977171805

# %% [markdown]
# Determining and printing mode of a feature from dataset

# %%
mode = data["hoursperweek"].mode()
print(mode)
# Out:
# 0    40
# dtype: int64

# %% [markdown]
# Determining and printing median of a feature from dataset

# %%
medianofage = data["age"].median()
print(medianofage)
# Out:
# 37.0

# %% [markdown]
# Determining and printing standard deviation of a feature from dataset

# %%
std = data["hoursperweek"].std()
print(std)
# Out:
# 12.34528507013169

# %% [markdown]
# Determining and printing variance of a feature from dataset

# %%
from statistics import variance
var = variance(data["hoursperweek"])
print(var)
# Out:
# 152.40606346281086

# %% [markdown]
# Determining correlation

# %%
data.corr()
# Out:
#                    age  capitalgain  capitalloss  hoursperweek
# age           1.000000     0.077490     0.057282      0.068299
# capitalgain   0.077490     1.000000    -0.031499      0.079112
# capitalloss   0.057282    -0.031499     1.000000      0.053106
# hoursperweek  0.068299     0.079112     0.053106      1.000000

# %% [markdown]
# Check missing values in dataset

# %%
data.isnull()
# Out:
#          age  JobType  EdType  maritalstatus  occupation  relationship   race  \
# 0      False    False   False          False       False         False  False
# 1      False    False   False          False       False         False  False
# 2      False    False   False          False       False         False  False
# 3      False    False   False          False       False         False  False
# 4      False    False   False          False       False         False  False
# ...      ...      ...     ...            ...         ...           ...    ...
# 31973  False    False   False          False       False         False  False
# 31974  False    False   False          False       False         False  False
# 31975  False    False   False          False       False         False  False
# 31976  False    False   False          False       False         False  False
# 31977  False    False   False          False       False         False  False
#
# ...

# %%
data.isnull().sum()
# Out:
# age              0
# JobType          0
# EdType           0
# maritalstatus    0
# occupation       0
# relationship     0
# race             0
# gender           0
# capitalgain      0
# capitalloss      0
# hoursperweek     0
# nativecountry    0
# SalStat          0
# dtype: int64

# %% [markdown]
# no missing values

# %% [markdown]
# Determining covariance

# %%
data.cov()
# Out:
#                       age   capitalgain    capitalloss  hoursperweek
# age            186.652557  7.726833e+03     314.284334     11.519501
# capitalgain   7726.833434  5.326951e+07  -92324.837921   7128.231521
# capitalloss    314.284334 -9.232484e+04  161277.982941    263.291140
# hoursperweek    11.519501  7.128232e+03     263.291140    152.406063
